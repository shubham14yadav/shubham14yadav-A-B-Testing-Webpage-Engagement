# %% [markdown]
# <a href="https://colab.research.google.com/github/shubham14yadav/shubham14yadav-A-B-Testing-Webpage-Engagement/blob/main/A_B_Testing_Webpage_Engagement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

df = pd.read_csv('webpage_engagement_data.csv')

# Separating the data into two groups
group_a = df[df['Group'] == 'A']['Time_Spent']
group_b = df[df['Group'] == 'B']['Time_Spent']

# Data Visualization
plt.figure(figsize=(10, 6))
plt.hist(group_a, alpha=0.5, label='Group A (Control)')
plt.hist(group_b, alpha=0.5, label='Group B (Test)')
plt.title('Distribution of Engagement Time for Two Web Page Designs')
plt.xlabel('Time Spent on Page (seconds)')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# Statistical Testing: Independent t-test
t_stat, p_value = stats.ttest_ind(group_a, group_b)
print(f"T-statistic: {t_stat}, P-value: {p_value}")
# Out:
# T-statistic: -3.59719275974963, P-value: 0.00040627960203622703

# %% [markdown]
# **Data Simulation: We created two groups:**
#
# Group A (Control) with an average engagement time of 60 seconds.
# Group B (Test) with an average engagement time of 65 seconds.
# Both groups had the same sample size (100) and standard deviation (10 seconds).
# Data Visualization: The histogram shows the distribution of engagement times for both groups. This visual representation helps us see the overlap and differences between the two groups.
#
# **Statistical Testing**: We performed an independent t-test on the two groups. The t-test returned two values:
#
# **t_stat (T-statistic):** -3.597, which indicates the difference in means in terms of standard error.
# p_value: 0.0004, which is the probability of observing a difference as large as what is observed, even if the two groups are actually the same (null hypothesis is true).
#
# **Interpretation:**
# The p-value is significantly less than the common alpha level of 0.05, suggesting that the difference in mean engagement time between the two groups is statistically significant.
# Since Group B (Test) has a higher mean time spent, we could infer that the new page design (tested in Group B) might be more effective in engaging users than the current design (used in Group A).
